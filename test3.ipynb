# %%
import numpy as np
from src.ms import MarginalScreeningNorm
from sicore import RealSubset
from src.inference import compute_randomized_pdf, compute_randomized_cdf
import matplotlib.pyplot as plt

stat = 2.6
truncated_region = RealSubset([[1.3, 1.8], [2.0, 2.7]])

mu_list = np.linspace(-5.0, 5.0, 100)
pdf_list = [compute_randomized_pdf(stat, 1.0, 1.0, truncated_region, mu) for mu in mu_list]
# cdf_list = [compute_randomized_cdf(stat, 1.0, 1.0, truncated_region, mu) for mu in mu_list]

plt.plot(mu_list, pdf_list)
# plt.plot(mu_list, cdf_list)
